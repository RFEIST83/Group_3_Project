# %%
import pandas as pd 
import matplotlib 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier

# %%
circuits = pd.read_csv('..//Group_3_Project/F1/circuits.csv')
laptimes = pd.read_csv('../Group_3_Project/F1/lap_times.csv')
pitstops = pd.read_csv('../Group_3_Project/F1/pit_stops.csv')
seasons = pd.read_csv('../Group_3_Project/F1/seasons.csv' )
status = pd.read_csv('../Group_3_Project/F1/status.csv')
constructor_standings = pd.read_csv('../Group_3_Project/F1/constructor_standings.csv')
constructors = pd.read_csv('../Group_3_Project/F1/constructors.csv')
driver_standings = pd.read_csv('../Group_3_Project/F1/driver_standings.csv')                                    
drivers = pd.read_csv('../Group_3_Project/F1/drivers.csv')
races = pd.read_csv('../Group_3_Project/F1/races.csv')
constructor_results = pd.read_csv('../Group_3_Project/F1/constructor_results.csv')
results = pd.read_csv('../Group_3_Project/F1/results.csv')
qualifying = pd.read_csv('../Group_3_Project/F1/qualifying.csv')
pd.get_option("display.max_columns",None)
# Out:
# 20

# %%
# Get common column names
common_columns = set(circuits.columns)
for df in [laptimes, pitstops, seasons, status, constructor_standings, constructors, driver_standings, drivers, races, constructor_results, results, qualifying]:
    common_columns = common_columns.intersection(df.columns)

# Check if there are common columns
if not common_columns:
    print("No common columns found.")
else:
    # Display common column names
    print("Common Column Names:", common_columns)

    # Merge DataFrames using common columns
    merged_data = circuits.copy()  # Start with one DataFrame
    for df in [laptimes, pitstops, seasons, status, constructor_standings, constructors, driver_standings, drivers, races, constructor_results, results, qualifying]:
        merged_data = pd.merge(merged_data, df, on=list(common_columns), how='left')

    # Display the merged data
    pd.set_option("display.max_columns", None)
    print(merged_data)
# Out:
# No common columns found.

# %%
# Concatenate DataFrames vertically
combined_data = pd.concat([circuits, laptimes, pitstops, seasons, status, constructor_standings, constructors, driver_standings, drivers, races, constructor_results, results, qualifying], axis=0, ignore_index=True)

# Display the combined data
pd.set_option("display.max_columns", None)
print(combined_data)
# Out:
#         circuitId   circuitRef                            name      location  \
# 0             1.0  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1             2.0       sepang    Sepang International Circuit  Kuala Lumpur
# 2             3.0      bahrain   Bahrain International Circuit        Sakhir
# 3             4.0    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4             5.0     istanbul                   Istanbul Park      Istanbul
# ...           ...          ...                             ...           ...
# 659645        NaN          NaN                             NaN           NaN
# 659646        NaN          NaN                             NaN           NaN
# 659647        NaN          NaN                             NaN           NaN
# 659648        NaN          NaN                             NaN           NaN
# 659649        NaN          NaN                             NaN           NaN
#
# ...
